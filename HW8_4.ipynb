# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_html('https://tw.stock.yahoo.com/d/i/fgbuy_tse.html', encoding = 'big5')

# %%
stock = df[3]

# %%
stock
# Out:
#       0                1      2      3      4        5       6
# 0   名 次          股票代號/名稱    成交價    漲　跌   買超張數   外資持股張數  外資持股比率
# 1     1           3037欣興   50.0   △2.9  27931   619822  41.19%
# 2     2           2317鴻海   91.0   △3.1  24771  6191387  44.66%
# 3     3          2891中信金  21.90  △0.30  20216  7858936  40.30%
# 4     4           2313華通   50.1   △3.1  16788   325014  27.27%
# 5     5         2449京元電子  39.50  △2.65  16359   568197  46.46%
# 6     6           4938和碩   68.6   △1.9  13999  1109031  42.46%
# 7     7           1464得力  28.00  △2.05   5208    15932   4.14%
# 8     8           8150南茂  38.00  △2.05   4528   378873  52.09%
# 9     9           2367燿華  34.80  △0.90   4265   160267  25.87%
# 10   10          2301光寶科   50.6   △0.7   3474  1375398  58.50%
# 11   11  00637L元大滬深300正2  18.49  ▽0.18   3223    32728   2.15%
# 12   12  00672L元大S&P原油正2  14.98  △0.13   3175   288496  23.29%
# 13   13           2337旺宏  29.80  △1.05   3119   371759  20.20%
# ...

# %%
column_names = '名 次, 股票代號/名稱,成交價,漲　跌,買超張數,外資持股張數,外資持股比率'.split(',')

# %%
column_names
# Out:
# ['名 次', ' 股票代號/名稱', '成交價', '漲\u3000跌', '買超張數', '外資持股張數', '外資持股比率']

# %%
len(column_names)
# Out:
# 7

# %%
df = pd.read_html('https://tw.stock.yahoo.com/d/i/fgbuy_tse.html',names=column_namess, encoding = 'big5')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-da05c87c3e9a> in <module>
# ----> 1 df = pd.read_html('https://tw.stock.yahoo.com/d/i/fgbuy_tse.html',names=column_namess, encoding = 'big5')
#
# TypeError: read_html() got an unexpected keyword argument 'names'
